# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
excel_file = "13.xlsx"
xldata = pd.read_excel(excel_file, index_col=0)
#transposed_data = xldata.transpose()

heatmap_data = xldata
#heatmap_data = xldata


sns.heatmap(heatmap_data, center=0.3,cmap="hot",annot=True)
#plt.tight_layout()
plt.xlabel("Low frequency")
plt.ylabel("High frequency")
plt.title("Heatmap")
plt.show()
